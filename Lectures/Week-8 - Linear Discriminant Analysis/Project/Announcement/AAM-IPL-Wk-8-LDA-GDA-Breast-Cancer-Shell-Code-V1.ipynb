# %% [markdown]
# # AAM-IPL Week-8 LDA/GDA - Predicting Breast Cancer/Malignancy
# **Name of The Student**: <Student_Name> </br>
# **Roll No.**: <Student-Roll_Number>> </br>
# **Branch of Study**: <Student_Name> </br>
# **Department**: <Student_department> </br>
# **Semester**: <Student_Name> </br>
# **Email**: <GPREC_Email_Address> </br>
# **Guest Faculty and Instructor**: Venkateswar Reddy Melachervu, CTO, Brillium Technologies </br>
# **Program Coordinator**: Prof. V.Suresh, CSM, GPREC </br>
#
# **Project Implementation Details**: </br>
# <Project_Implementation_Details>
#
#
# **AAM-IPL of GPREC is brought to you by Brillium Technologies.**

# %%
# %pip install seaborn
# %pip install wordcloud
# %pip install scikit-learn
# %pip install matplotlib

# %%
# Assignment: Comparative Analysis of Classification Algorithms on the Breast Cancer Dataset with a focus on LDA/GDA

# Step 1: Import Necessary Libraries
# Hint: Import libraries like numpy, pandas, seaborn, matplotlib, and scikit-learn modules for models and metrics.

# Step 2: Load and Preprocess Dataset
# Load the Breast Cancer dataset and convert it to a DataFrame.
# Hint: Use `load_breast_cancer()` from sklearn and convert to a DataFrame.

# Step 3: Split Dataset into Training and Test Sets
# Split the data with a test size of 20%.
# Hint: Use `train_test_split()` from sklearn with `stratify=y`.

# Step 4: Standardize Features
# Standardize the dataset for optimal model performance.
# Hint: Use `StandardScaler()` to fit and transform the data.

# Step 5: Define Models
# Define a dictionary containing all the models you will use.
# Include: Logistic Regression, LDA, GDA, SVM, KNN, Naive Bayes, Decision Tree, Random Forest, and K-Means Clustering.

# Step 6: Initialize Results List
# Create an empty list called `results` to store each model’s evaluation metrics.

# Step 7: Function to Add Watermark to Plots
# Define a function to add the AAM-IPL watermark to each plot.
# The watermark image file should be named 'AAM-IPL-Watermark-for-Plots.png' and located in the working directory.

def add_aam_ipl_watermark(ax, watermark_image_path, zoom=0.4, alpha=0.3, rotation_angle=45):
    """
    Adds a diagonal watermark to the plot.
    
    Parameters:
    - ax: The plot axis to add the watermark to.
    - watermark_image_path: Path to the watermark image.
    - zoom: Scale of the watermark.
    - alpha: Transparency of the watermark.
    - rotation_angle: Angle to rotate the watermark.
    """
    from matplotlib.offsetbox import OffsetImage, AnnotationBbox
    from matplotlib.transforms import Affine2D
    watermark_image = plt.imread(watermark_image_path)  # Load the image
    
    # Create the watermark and add it to the axis
    imagebox = OffsetImage(watermark_image, alpha=alpha, zoom=zoom)
    trans = Affine2D().rotate_deg(rotation_angle) + ax.transData
    ab = AnnotationBbox(imagebox, (0.5, 0.5), frameon=False, xycoords='axes fraction', boxcoords="axes fraction", pad=0, transform=trans)
    ax.add_artist(ab)

# Example Usage:
# After creating each plot, call the function with the appropriate axis and image path.
# ax = plt.gca()
# add_aam_ipl_watermark(ax, 'AAM-IPL-Watermark-for-Plots.png')

# Step 8: Train Models and Evaluate
# Loop over each model:
# - Train the model
# - Record training time and prediction time
# - Calculate accuracy, precision, recall, F1 score, ROC AUC, and confusion matrix
# - Handle clustering model (K-Means) separately as it’s unsupervised
# Hint: Use `time.time()` to measure training and prediction times.

# Step 9: Convert Results to DataFrame
# Convert the `results` list to a DataFrame for easier plotting and analysis.

# Step 10: Plotting Metrics and Times
# Plot the training time, prediction time, and each performance metric.
# Hint: Use seaborn’s `barplot()` for visualization.
# Remember to call `add_aam_ipl_watermark()` to add the watermark to each plot.

# Step 11: Plot Combined ROC Curves
# Plot ROC curves for models that support probability prediction.
# Hint: Use `roc_curve` and `plt.plot` for each model.
# Call `add_aam_ipl_watermark()` to add the watermark to this plot.

# Step 12: Plot Combined Confusion Matrices
# Use subplots to plot the confusion matrices of each model in a single figure.
# Make sure to exclude K-Means.
# Hint: Use seaborn’s `heatmap()` with `confusion_matrix()`.
# Add watermark by calling `add_aam_ipl_watermark()`.

# %%
# Generate the PDF of code and output of project jupyter file
# !jupyter nbconvert --to pdf AAM-IPL-Wk-8-LDA-GDA-Breast-Cancer-Shell-Code-V1.ipynb

# Submit the PDF and .ipynb file in AAM-IPL Online Classroom on Google Class
